# %% [markdown]
# # Vehicle Damage Severity Detection –  Image Classification Algorithm
#
# ### Rohit Gulve, Nikhita Kannam, Jose Salas, Lizzette Salmeron
# ### Department of Computer Science, Grove School of Engineering, The City College of New York

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# # Follow the format for the Section/Subsections (open this cell to look at the number of # and *
# # Section X: (Section Title)
# ## Subsection X.1 – (Subsection Title)
# ### *Sub-SubSection X.1.1* –
# ### *Sub-Sub-SubSection X.1.1.1* –
# #### *Sub-Sub-Sub-SubSection X.1.1.1* –
#
# Writing is done in normal format

# %% [markdown]
# _______________________________________________

# %% [markdown]
# # Format for Code Snippets or code inclusion

# %% [markdown]
# ### Include code snippet (Edit > Insert Image) Example Below:

# %% [markdown]
# ![Screen%20Shot%202023-05-08%20at%206.55.54%20PM.png](attachment:Screen%20Shot%202023-05-08%20at%206.55.54%20PM.png)

# %% [markdown]
# ### Or actual code but it has to be all in a single cell

# %% [markdown]
# __________________________________________

# %% [markdown]
# # Section 1: Introduction

# %% [markdown]
# # Section 2: Data Agumentation

# %% [markdown]
# Explain how many times the data was agumented/increased in size (each time) — how and where we used this data will be explained in the other sections
#
# Started with 1631 images, increased to:
# - 3000 images?
# - 5000 images?
# - 8000 images
# - 10000 images

# %% [markdown]
# # Section 3: Baseline Models Using Image-to-CSV Data Format

# %% [markdown]
# ## Section 3.1 – EDA

# %% [markdown]
# Everyone should combine the EDA results here, it will not make sense to have multiple people saying the same thing

# %% [markdown]
# ## Section 3.2 –  Multiple Model Comparison

# %% [markdown]
# ## Section 3.3 – KNN

# %% [markdown]
# ## Section 3.4 – Naive Bayes

# %% [markdown]
# ## Section 3.5 – Decision Trees

# %% [markdown]
# # Section 4: Image-to-Numpy Array Data Format—Feature Engineering and Baseline Models

# %% [markdown]
# ## Section 4.1 – EDA

# %% [markdown]
# Everyone should combine the EDA results here, it will not make sense to have multiple people saying the same thing

# %% [markdown]
# ## Section 4.2 – Feature Engineering

# %% [markdown]
# ### *Section 4.2.1* – SURF

# %% [markdown]
# ### *Section 4.2.2* – SIFT

# %% [markdown]
# ### *Section 4.2.3* – Edge Detection

# %% [markdown]
# ### *Section 4.2.4* – Blobs

# %% [markdown]
# ### *Section 4.2.5* – Gabor

# %% [markdown]
# ### *Section 4.2.6* – Corners

# %% [markdown]
# ### *Section 4.2.7* – (Any other filter that was left out)

# %% [markdown]
# ## Section 4.3 – Histograms and Statistics on Best Features

# %% [markdown]
# ## Section 4.4 – CNN Feature Extraction

# %% [markdown]
# ## Section 4.5 – Deep Learning

# %% [markdown]
# ## Section 4.6 – Machine Learning Models on Best Features

# %% [markdown]
# ### *Section 4.6.1 – (Feature Name)*

# %% [markdown]
# #### *Section 4.6.1.1 – (ML Model Name)*

# %% [markdown]
# ### *Section 4.6.2 – (Feature Name)*

# %% [markdown]
# #### *Section 4.6.2.1 – (ML Model Name)*

# %% [markdown]
# ### *Section 4.6.X – CNN*

# %% [markdown]
# #### *Section 4.6.X.X – (ML Model Name)*

# %% [markdown]
# ### Section 4.5.X – Deep Learning

# %% [markdown]
# #### *Section 4.5.X.X – (ML Model Name)*

# %% [markdown]
# # Section 5: Results Evaluation

# %% [markdown]
# A final summary of all results, perhaps using tables and other visuals to compare accuracies and other report values.

# %% [markdown]
# # Section 6: References

# %% [markdown]
#     [1]
#     [2]
#     [3]
