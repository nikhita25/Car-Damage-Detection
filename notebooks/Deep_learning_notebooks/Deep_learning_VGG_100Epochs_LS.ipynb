# %% [markdown]
# # Importing Libraries

# %%
import os                   
import cv2  
import h5py
from tqdm import tqdm
import random as rn
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
# % matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder    #For encoding categorical variables
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier,GradientBoostingClassifier
from sklearn import metrics

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import load_model

from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3
# from keras.applications.resnet50 import ResNet50

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing 128x128 numpy image data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
array_128x128_final = np.load("/content/drive/MyDrive/Colab Notebooks/numpy_data_CNN_128*128.npz", allow_pickle=True)

# %% [markdown]
# # Train-Test-Split

# %%
X_train = array_128x128_final['X_train']
y_train = array_128x128_final['y_train']
X_test = array_128x128_final['X_test']
y_test = array_128x128_final['y_test']

# %%
print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (6052, 128, 128, 3)
# y_train shape: (6052,)
# X_test shape: (1514, 128, 128, 3)
# y_test shape: (1514,)

# %% [markdown]
# # Plotting single image from numpy data

# %%
plt.subplot(121)
img = np.reshape(X_train[1], (128,128,3))
plt.imshow(img)

# %% [markdown]
# # Running VGG Deep Learning model (100 Epochs)
#
# ##### Load the ImageNet VGG model. Notice we exclude the densely connected layer at the top
#
# ##### And then we add the VGG Model directly to our new model

# %%
NUM_EPOCHS = 100
keep_prob = 0.5
vggModel= tf.keras.applications.VGG16( weights='imagenet', include_top=False, input_shape=(128, 128, 3))

vggModel.trainable= False

model = tf.keras.models.Sequential()
model.add(vggModel)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(rate = 1 - keep_prob))
model.add(tf.keras.layers.Dense(17, activation='softmax'))

print (model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 256)               2097408
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 17)                4369
#
# =================================================================
# Total params: 16,816,465
# Trainable params: 2,101,777
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %% [markdown]
# ##### Saving the model during training

# %%
save_at = "/content/drive/MyDrive/model.hdf5"
save_best = ModelCheckpoint (save_at, monitor='val_accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='max')

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01),metrics=['accuracy'])

#  = model.fit(X_train, y_train, epochs=NUM_EPOCHS, batch_size=32, validation_data=(X_test, y_test))
H = model.fit(X_train, y_train, epochs=NUM_EPOCHS, batch_size=32, validation_data=(X_test, y_test), callbacks=[save_best])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1
# Epoch 66/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.8061 - accuracy: 0.5426 - val_loss: 1.0400 - val_accuracy: 0.6189
# Epoch 67/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.8021 - accuracy: 0.5410 - val_loss: 0.9759 - val_accuracy: 0.6235
# Epoch 68/100
# 190/190 [==============================] - 11s 55ms/step - loss: 0.7972 - accuracy: 0.5430 - val_loss: 1.0183 - val_accuracy: 0.6268
# Epoch 69/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7938 - accuracy: 0.5484 - val_loss: 1.1498 - val_accuracy: 0.6275
# Epoch 70/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7784 - accuracy: 0.5689 - val_loss: 0.9435 - val_accuracy: 0.6182
# Epoch 71/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7820 - accuracy: 0.5562 - val_loss: 1.3043 - val_accuracy: 0.6235
# Epoch 72/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7905 - accuracy: 0.5567 - val_loss: 1.0529 - val_accuracy: 0.6176
# Epoch 73/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7793 - accuracy: 0.5623 - val_loss: 1.0181 - val_accuracy: 0.6196
# Epoch 74/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7986 - accuracy: 0.5473 - val_loss: 1.0587 - val_accuracy: 0.6242
# Epoch 75/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7861 - accuracy: 0.5540 - val_loss: 0.9241 - val_accuracy: 0.6235
# Epoch 76/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7865 - accuracy: 0.5563 - val_loss: 1.0397 - val_accuracy: 0.6242
# Epoch 77/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7899 - accuracy: 0.5610 - val_loss: 1.2463 - val_accuracy: 0.6110
# Epoch 78/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7995 - accuracy: 0.5496 - val_loss: 1.2406 - val_accuracy: 0.6295
# Epoch 79/100
# 190/190 [==============================] - 10s 53ms/step - loss: 0.7996 - accuracy: 0.5479 - val_loss: 1.0203 - val_accuracy: 0.6215
# Epoch 80/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7889 - accuracy: 0.5603 - val_loss: 1.0534 - val_accuracy: 0.6189
# Epoch 81/100
# 190/190 [==============================] - 12s 63ms/step - loss: 0.7833 - accuracy: 0.5568 - val_loss: 1.1145 - val_accuracy: 0.6321
# Epoch 82/100
# 190/190 [==============================] - 10s 55ms/step - loss: 0.7763 - accuracy: 0.5633 - val_loss: 1.5353 - val_accuracy: 0.6321
# Epoch 83/100
# 190/190 [==============================] - 10s 53ms/step - loss: 0.7774 - accuracy: 0.5689 - val_loss: 1.1294 - val_accuracy: 0.6202
# Epoch 84/100
# 190/190 [==============================] - 10s 53ms/step - loss: 0.7893 - accuracy: 0.5547 - val_loss: 1.1382 - val_accuracy: 0.6202
# Epoch 85/100
# 190/190 [==============================] - 12s 62ms/step - loss: 0.7842 - accuracy: 0.5575 - val_loss: 1.1029 - val_accuracy: 0.6328
# Epoch 86/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7971 - accuracy: 0.5572 - val_loss: 1.0923 - val_accuracy: 0.6288
# Epoch 87/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7772 - accuracy: 0.5598 - val_loss: 1.2228 - val_accuracy: 0.6268
# Epoch 88/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7746 - accuracy: 0.5712 - val_loss: 1.3130 - val_accuracy: 0.6229
# Epoch 89/100
# 190/190 [==============================] - 10s 53ms/step - loss: 0.7802 - accuracy: 0.5649 - val_loss: 1.1179 - val_accuracy: 0.6268
# Epoch 90/100
# 190/190 [==============================] - 10s 55ms/step - loss: 0.7716 - accuracy: 0.5653 - val_loss: 1.4370 - val_accuracy: 0.6248
# Epoch 91/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7690 - accuracy: 0.5762 - val_loss: 1.1517 - val_accuracy: 0.6209
# Epoch 92/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7790 - accuracy: 0.5573 - val_loss: 1.1824 - val_accuracy: 0.6268
# Epoch 93/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7648 - accuracy: 0.5682 - val_loss: 1.1533 - val_accuracy: 0.6301
# Epoch 94/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7693 - accuracy: 0.5739 - val_loss: 1.1433 - val_accuracy: 0.6255
# Epoch 95/100
# 190/190 [==============================] - 10s 52ms/step - loss: 0.7568 - accuracy: 0.5775 - val_loss: 1.8077 - val_accuracy: 0.6248
# Epoch 96/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7672 - accuracy: 0.5715 - val_loss: 1.2677 - val_accuracy: 0.6255
# Epoch 97/100
# 190/190 [==============================] - 10s 53ms/step - loss: 0.7701 - accuracy: 0.5651 - val_loss: 1.2982 - val_accuracy: 0.6281
# Epoch 98/100
# 190/190 [==============================] - 11s 56ms/step - loss: 0.7584 - accuracy: 0.5765 - val_loss: 1.3636 - val_accuracy: 0.6268
# Epoch 99/100
# 190/190 [==============================] - 10s 53ms/step - loss: 0.7610 - accuracy: 0.5732 - val_loss: 1.4926 - val_accuracy: 0.6222
# Epoch 100/100
# 190/190 [==============================] - 11s 57ms/step - loss: 0.7586 - accuracy: 0.5778 - val_loss: 1.4922 - val_accuracy: 0.6248

# %% [markdown]
# # Running model on Test Set

# %%
model = load_model('/content/drive/MyDrive/model.hdf5')
score = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# Accuracy over the test set:
#   63.28 %

# %%
y_test
# Out:
# array([2, 1, 1, ..., 1, 2, 1])

# %%
encoder = LabelEncoder()
Targets = encoder.fit_transform(y_test)
Targets
Targets.shape
# Out:
# (1514,)

# %% [markdown]
# # Predicting damage severity on random images

# %%
Y_pred = np.round(model.predict(X_test))

np.random.seed(87)
for rand_num in np.random.randint(0, len(y_test), 10):
  plt.figure()
  plt.imshow(X_test[rand_num]), plt.axis('off')
  if np.where(Y_pred[rand_num] == 1)[0].sum() == np.where(y_test[rand_num] == 1)[0].sum():
    plt.title(encoder.classes_[np.where(Y_pred[rand_num] == 1)[0].sum()], color='g')
  else :
    plt.title(encoder.classes_[np.where(Y_pred[rand_num] == 1)[0].sum()], color='r')
# Out:
# 48/48 [==============================] - 2s 41ms/step
